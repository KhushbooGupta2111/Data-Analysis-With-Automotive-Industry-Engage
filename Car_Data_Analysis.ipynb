# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushbooGupta2111/Data-Analysis-With-Automotive-Industry-Engage/blob/main/Car_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# drive.mount('/content/gdrive', force_remount=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
auto_data = pd.read_csv('gdrive/My Drive/Auto_Clean_Final.csv')

# %%
auto_data = auto_data.iloc[: , 1:]

# %%
auto_data.columns.tolist()
# Out:
# ['Make',
#  'Model',
#  'Ex-Showroom_Price',
#  'Displacement',
#  'Cylinders',
#  'Valves_Per_Cylinder',
#  'Drivetrain',
#  'Emission_Norm',
#  'Engine_Location',
#  'Fuel_System',
#  'Fuel_Tank_Capacity',
#  'Fuel_Type',
#  'Height',
#  'Length',
#  'Width',
#  'Body_Type',
#  'Doors',
#  'Mileage',
#  'Gears',
#  'Ground_Clearance',
#  'Front_Brakes',
#  'Rear_Brakes',
#  'Power_Windows',
#  'Power_Seats',
#  'Power',
#  'Torque',
#  'Odometer',
#  'Speedometer',
#  'Tachometer',
#  'Seating_Capacity',
#  'Seats_Material',
#  'Type',
#  'Start_/_Stop_Button',
#  '12v_Power_Outlet',
#  'Aux-in_Compatibility',
#  'Average_Fuel_Consumption',
#  'Basic_Warranty_Years',
#  'Bluetooth',
#  'Boot-lid_Opener',
#  'Boot_Space',
#  'CD_/_MP3_/_DVD_Player',
#  'Central_Locking',
#  'Child_Safety_Locks',
#  'Clock',
#  'Cup_Holders',
#  'Distance_to_Empty',
#  'Door_Pockets',
#  'Engine_Malfunction_Light',
#  'Extended_Warranty',
#  'FM_Radio',
#  'Fuel-lid_Opener',
#  'Fuel_Gauge',
#  'Handbrake',
#  'Instrument_Console',
#  'Low_Fuel_Warning',
#  'Minimum_Turning_Radius',
#  'Multifunction_Display',
#  'Sun_Visor',
#  'Third_Row_AC_Vents',
#  'Auto-Dimming_Rear-View_Mirror',
#  'Hill_Assist',
#  'Gear_Indicator',
#  '3_Point_Seat-Belt_in_Middle_Rear_Seat',
#  'Ambient_Lightning',
#  'Cargo/Boot_Lights',
#  'Drive_Modes',
#  'Engine_Immobilizer',
#  'High_Speed_Alert_System',
#  'Lane_Watch_Camera/_Side_Mirror_Camera',
#  'Passenger_Side_Seat-Belt_Reminder',
#  'Seat_Back_Pockets',
#  'Voice_Recognition',
#  'Walk_Away_Auto_Car_Lock',
#  'ABS_(Anti-lock_Braking_System)',
#  'Headlight_Reminder',
#  'Airbags',
#  'Door_Ajar_Warning',
#  'EBD_(Electronic_Brake-force_Distribution)',
#  'Fasten_Seat_Belt_Warning',
#  'Gear_Shift_Reminder',
#  'Number_of_Airbags',
#  'Parking_Assistance',
#  'Key_Off_Reminder',
#  'USB_Compatibility',
#  'Android_Auto',
#  'Apple_CarPlay',
#  'Cigarette_Lighter',
#  'Infotainment_Screen',
#  'Multifunction_Steering_Wheel',
#  'Average_Speed',
#  'EBA_(Electronic_Brake_Assist)',
#  'Seat_Height_Adjustment',
#  'Navigation_System',
#  'Second_Row_AC_Vents',
#  'Tyre_Pressure_Monitoring_System',
#  'Rear_Center_Armrest',
#  'iPod_Compatibility',
#  'ESP_(Electronic_Stability_Program)',
#  'Cooled_Glove_Box',
#  'Heated_Seats',
#  'Turbocharger',
#  'ISOFIX_(Child-Seat_Mount)',
#  'Rain_Sensing_Wipers',
#  'Paddle_Shifters',
#  'Leather_Wrapped_Steering',
#  'Automatic_Headlamps',
#  'ASR_/_Traction_Control',
#  'Cruise_Control',
#  'USB_Ports',
#  'Heads-Up_Display',
#  'Welcome_Lights',
#  'Battery',
#  'Electric_Range',
#  'Basic_Warranty_Distance']

# %%
company_dictionary = auto_data["Make"].value_counts().to_dict()
print(company_dictionary)
# Out:
# {'Maruti Suzuki': 163, 'Hyundai': 130, 'Mahindra': 119, 'Tata': 100, 'Toyota': 82, 'Honda': 64, 'Mercedes': 57, 'Ford': 43, 'Skoda': 43, 'Bmw': 37, 'Renault': 36, 'Volkswagen': 34, 'Audi': 31, 'Nissan': 29, 'Jeep': 28, 'Land Rover Rover': 27, 'Datsun': 24, 'Fiat': 23, 'Jaguar': 22, 'Kia': 21, 'Volvo': 18, 'Porsche': 14, 'Lamborghini': 13, 'Mg': 13, 'Icml': 11, 'Mini': 10, 'Land Rover': 10, 'Lexus': 10, 'Rolls-Royce': 9, 'Maserati': 9, 'Ferrari': 8, 'Mitsubishi': 7, 'Force': 6, 'Bentley': 6, 'Premier': 6, 'Isuzu': 5, 'Aston Martin': 3, 'Bugatti': 2, 'Bajaj': 2, 'Dc': 1}

# %%
# auto_data.groupby(['Make']).sum().plot(kind='pie', y='Make')
company_dataframe = pd.DataFrame(company_dictionary.items(), columns=['Company', 'Amount'])
company_dataframe.groupby(['Company']).sum().plot(kind='pie', y='Amount' , legend=None)

# %%
auto_data.describe()
# Out:
#        Ex-Showroom_Price  Displacement    Cylinders  Valves_Per_Cylinder  \
# count       1.276000e+03   1276.000000  1276.000000          1273.000000
# mean        4.596538e+06   1844.444357     4.344828             3.956009
# std         1.214735e+07   1073.682170     1.664456             0.851163
# min         2.364470e+05      0.000000     0.000000             0.000000
# 25%         7.438760e+05   1198.000000     4.000000             4.000000
# 50%         1.060064e+06   1497.000000     4.000000             4.000000
# 75%         2.979828e+06   1998.000000     4.000000             4.000000
# max         2.121554e+08   7993.000000    16.000000            16.000000
#
#        Emission_Norm  Fuel_Tank_Capacity       Height       Length  \
# count    1276.000000         1276.000000  1276.000000  1276.000000
# mean        4.549373           52.260893  1589.847057  4296.883730
# std         1.012816           17.260981   164.018243   476.612977
# min         0.000000            0.000000     0.000000     4.640000
# 25%         4.000000           40.000000  1495.000000  3991.750000
# 50%         4.000000           48.000000  1557.000000  4331.000000
# 75%         6.000000           60.000000  1666.000000  4620.000000
# max         6.000000          105.000000  2670.000000  6092.000000
#
#              Width        Doors       Mileage        Gears  Ground_Clearance  \
# count  1276.000000  1276.000000   1276.000000  1276.000000       1276.000000
# mean   1771.730286     4.551724     31.760298     5.880094        147.360502
# std     228.889609     0.747065    728.513775     1.305390         74.627234
# min       0.000000     2.000000      0.000000     1.000000          0.000000
# 25%    1695.000000     4.000000      0.000000     5.000000        152.000000
# 50%    1770.000000     5.000000     12.000000     5.000000        167.000000
# 75%    1850.500000     5.000000     18.490000     7.000000        190.000000
# max    2226.000000     5.000000  26032.000000    10.000000        498.000000
#
#        Seating_Capacity  Basic_Warranty_Years  Number_of_Airbags  USB_Ports  \
# count       1276.000000           1276.000000        1276.000000  29.000000
# mean           5.269592              1.945925           3.386364   1.793103
# std            1.148319              3.058549           2.654559   0.773642
# min            2.000000              0.000000           0.000000   1.000000
# 25%            5.000000              0.000000           2.000000   1.000000
# 50%            5.000000              2.000000           2.000000   2.000000
# 75%            5.000000              3.000000           6.000000   2.000000
# max           16.000000             24.000000          14.000000   3.000000
#
#        Basic_Warranty_Distance
# count             1.276000e+03
# mean              3.473365e+09
# std               6.598752e+09
# min               0.000000e+00
# 25%               0.000000e+00
# 50%               0.000000e+00
# 75%               7.500000e+04
# max               1.600006e+10

# %%
auto_data_correlation = auto_data.corr()

# %%
# plt.figure(figsize=(10,10))
# sns.heatmap(auto_data_correlation[["Ex-Showroom_Price" , "Displacement" , "Basic_Warranty_Years" , "Number_of_Airbags" , "Emission_Norm"]] , cmap="Greens" , annot=True , fmt = '.2f')

# %%
numeric_data_list = auto_data._get_numeric_data().columns.tolist()

# %%
categoric_data_list = [col for col in auto_data.columns if col not in numeric_data_list]

# %%
print(numeric_data_list)
# Out:
# ['Ex-Showroom_Price', 'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Emission_Norm', 'Fuel_Tank_Capacity', 'Height', 'Length', 'Width', 'Doors', 'Mileage', 'Gears', 'Ground_Clearance', 'Seating_Capacity', 'Basic_Warranty_Years', 'Number_of_Airbags', 'USB_Ports', 'Basic_Warranty_Distance']

# %%
print(categoric_data_list)
# Out:
# ['Make', 'Model', 'Drivetrain', 'Engine_Location', 'Fuel_System', 'Fuel_Type', 'Body_Type', 'Front_Brakes', 'Rear_Brakes', 'Power_Windows', 'Power_Seats', 'Power', 'Torque', 'Odometer', 'Speedometer', 'Tachometer', 'Seats_Material', 'Type', 'Start_/_Stop_Button', '12v_Power_Outlet', 'Aux-in_Compatibility', 'Average_Fuel_Consumption', 'Bluetooth', 'Boot-lid_Opener', 'Boot_Space', 'CD_/_MP3_/_DVD_Player', 'Central_Locking', 'Child_Safety_Locks', 'Clock', 'Cup_Holders', 'Distance_to_Empty', 'Door_Pockets', 'Engine_Malfunction_Light', 'Extended_Warranty', 'FM_Radio', 'Fuel-lid_Opener', 'Fuel_Gauge', 'Handbrake', 'Instrument_Console', 'Low_Fuel_Warning', 'Minimum_Turning_Radius', 'Multifunction_Display', 'Sun_Visor', 'Third_Row_AC_Vents', 'Auto-Dimming_Rear-View_Mirror', 'Hill_Assist', 'Gear_Indicator', '3_Point_Seat-Belt_in_Middle_Rear_Seat', 'Ambient_Lightning', 'Cargo/Boot_Lights', 'Drive_Modes', 'Engine_Immobilizer', 'High_Speed_Alert_System', 'Lane_Watch_Camera/_Side_Mirror_Camera', 'Passenger_Side_Seat-Belt_Reminder', 'Seat_Back_Pockets', 'Voice_Recognition', 'Walk_Away_Auto_Car_Lock', 'ABS_(Anti-lock_Braking_System)', 'Headlight_Reminder', 'Airbags', 'Door_Ajar_Warning', 'EBD_(Electronic_Brake-force_Distribution)', 'Fasten_Seat_Belt_Warning', 'Gear_Shift_Reminder', 'Parking_Assistance', 'Key_Off_Reminder', 'USB_Compatibility', 'Android_Auto', 'Apple_CarPlay', 'Cigarette_Lighter', 'Infotainment_Screen', 'Multifunction_Steering_Wheel', 'Average_Speed', 'EBA_(Electronic_Brake_Assist)', 'Seat_Height_Adjustment', 'Navigation_System', 'Second_Row_AC_Vents', 'Tyre_Pressure_Monitoring_System', 'Rear_Center_Armrest', 'iPod_Compatibility', 'ESP_(Electronic_Stability_Program)', 'Cooled_Glove_Box', 'Heated_Seats', 'Turbocharger', 'ISOFIX_(Child-Seat_Mount)', 'Rain_Sensing_Wipers', 'Paddle_Shifters', 'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'ASR_/_Traction_Control', 'Cruise_Control', 'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range']

# %%
# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()

# %%
# for column_name in categoric_data_list:
#   auto_data[column_name] = label_encoder.fit_transform(auto_data[column_name])

# %%
auto_data_correlations = auto_data.corr()
plt.figure(figsize=(5,120))
sns.heatmap(auto_data_correlations[["Ex-Showroom_Price"]].sort_values(by=['Ex-Showroom_Price'],ascending=False) , cmap="Greens" , annot=True , fmt = '.2f')

# %%
# from sklearn.feature_selection import VarianceThreshold
# variance_threshold = VarianceThreshold(threshold=100)
# variance_threshold.fit(auto_data.drop(labels = ['Ex-Showroom_Price'] , axis = 1))

# %% [markdown]
# Graphs and Analysis 🙈
# Yatharth Tyagi 🙈

# %%
# auto_data.hist(figsize=(50,50) , align = 'mid')

# %%
car = auto_data["Body_Type"].value_counts().to_dict()
car_dataframe = pd.DataFrame(car.items(), columns=['Body Type', 'Types'])
car_dataframe.groupby(['Body Type']).sum().plot(kind='pie', y='Types' , legend=True , labels = None, autopct='%1.1f%%', figsize=(10, 20))
plt.title("Different Car Body Types", fontsize=14);

# %%
car = auto_data["Fuel_Type"].value_counts().to_dict()
car_dataframe = pd.DataFrame(car.items(), columns=['Fuel_Categories', 'Types'])
car_dataframe.groupby(['Fuel_Categories']).sum().plot(kind='pie', y='Types' , legend=True , labels = None, autopct='%1.1f%%', figsize=(10, 20))
plt.title("Different Car Fuel_Categoriess", fontsize=14);

# %%
car = auto_data["Drivetrain"].value_counts().to_dict()
car_dataframe = pd.DataFrame(car.items(), columns=['Fuel_Categories', 'Types'])
car_dataframe.groupby(['Fuel_Categories']).sum().plot(kind='pie', y='Types' , legend=True , labels = None, autopct='%1.1f%%', figsize=(10, 20))
plt.title("Different Car Fuel_Categoriess", fontsize=14);
